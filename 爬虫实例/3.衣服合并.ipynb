# %%
import os
import time
import re
import requests
import json
import pandas as pd
from pandas import Series, DataFrame

# %%
renttherunway_0000_1000 = pd.read_csv("renttherunway_0000_1000.csv",
                                      index_col=0)
renttherunway_1000_2000 = pd.read_csv("renttherunway_1000_2000.csv",
                                      index_col=0)
renttherunway_2000_3000 = pd.read_csv("renttherunway_2000_3000.csv",
                                      index_col=0)
renttherunway_3000_4000 = pd.read_csv("renttherunway_3000_4000.csv",
                                      index_col=0)
renttherunway_4000_5000 = pd.read_csv("renttherunway_4000_5000.csv",
                                      index_col=0)
renttherunway_5000_fi = pd.read_csv("renttherunway_5000_fi.csv", index_col=0)

renttherunway_result = renttherunway_0000_1000.append([
    renttherunway_1000_2000, renttherunway_2000_3000, renttherunway_3000_4000,
    renttherunway_4000_5000, renttherunway_5000_fi
])

renttherunway_result.head()
# Out:
#                                              url  \
# 0  https://www.renttherunway.com/pdp/items/IRO39
# 1  https://www.renttherunway.com/pdp/items/ELK27
# 2  https://www.renttherunway.com/pdp/items/GRJ18
# 3  https://www.renttherunway.com/pdp/items/IRO40
# 4  https://www.renttherunway.com/pdp/items/DLC29
#
#                             name              designer price  \
# 0                     Irina Coat                   Iro  $130
# 1  Kulture Wrap Blockknit Poncho                   Elk   $45
# 2    Palm Printed Wide Leg Pants           Great Jones   $50
# 3                     Awa Jacket                   Iro  $160
# 4          Black Military Blazer  Derek Lam Collective   $65
#
#                                                 size  \
# 0                                       Sized: 32-44
# 1                                    Sized: One Size
# 2  Sized: 0-16, one length available. Regular mea...
# 3                                        Sized:32-44
# ...

# %%
print(renttherunway_result.shape)
renttherunway_result.head()
# Out:
# (6121, 8)
#                                              url  \
# 0  https://www.renttherunway.com/pdp/items/IRO39
# 1  https://www.renttherunway.com/pdp/items/ELK27
# 2  https://www.renttherunway.com/pdp/items/GRJ18
# 3  https://www.renttherunway.com/pdp/items/IRO40
# 4  https://www.renttherunway.com/pdp/items/DLC29
#
#                             name              designer price  \
# 0                     Irina Coat                   Iro  $130
# 1  Kulture Wrap Blockknit Poncho                   Elk   $45
# 2    Palm Printed Wide Leg Pants           Great Jones   $50
# 3                     Awa Jacket                   Iro  $160
# 4          Black Military Blazer  Derek Lam Collective   $65
#
#                                                 size  \
# 0                                       Sized: 32-44
# 1                                    Sized: One Size
# 2  Sized: 0-16, one length available. Regular mea...
# 3                                        Sized:32-44
# ...

# %%
renttherunway_result.to_csv("renttherunway_result.csv")
